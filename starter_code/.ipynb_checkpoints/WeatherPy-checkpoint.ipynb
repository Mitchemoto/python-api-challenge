# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from openweatherkey import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 640

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# create lists to fill using for loop in api call
city_list=[]
cloudiness_list=[]
country_list=[]
date_list=[]
humidity_list=[]
lat_list=[]
lng_list=[]
max_temp_list=[]
wind_speed_list=[]


# create index counter at 0 and set the counter to 1
index_count=0
set_count=1

# %%
# get url setup for the json request
base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "Imperial"
updated_url = f"{base_url}units={units}&appid={weather_api_key}&q="

#print header data
print('Beginning Data Retrieval')
print('-----------------------------')

# start for loop uring try and except across all lists to fill lists, and omit missing data 
for city in cities:
    query_url=updated_url+city
    response=requests.get(query_url).json()
    #if statement for set count of 50
    if index_count < 50:
        index_count = index_count + 1
    else:
        set_count = set_count + 1
        index_count=0
        
# run print statement to print through record counter, index counter, and city
    print(f'Processing Record {index_count} of Set {set_count} | {city}')    
    try:
        city_list.append(response['name'])
        cloudiness_list.append(response['clouds']['all'])
        country_list.append(response['sys']['country'])
        date_list.append(response['dt'])
        humidity_list.append(response['main']['humidity'])
        lat_list.append(response['coord']['lat'])
        lng_list.append(response['coord']['lon'])
        max_temp_list.append(response['main']['temp_max'])
        wind_speed_list.append(response['wind']['speed'])
    except:
        print("City not found. Skipping...")
    
print('-----------------------------')
print('Data Retrieval Complete')      
print('-----------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | pisco
# Processing Record 2 of Set 1 | port lincoln
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | bluff
# Processing Record 5 of Set 1 | port elizabeth
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | itoman
# Processing Record 8 of Set 1 | luderitz
# Processing Record 9 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 1 | clyde river
# Processing Record 11 of Set 1 | lermontovka
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | chuy
# Processing Record 14 of Set 1 | giddalur
# Processing Record 15 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | labuhan
# Processing Record 18 of Set 1 | new norfolk
# Processing Record 19 of Set 1 | burgeo
# Processing Record 20 of Set 1 | mahebourg
# Processing Record 21 of Set 1 | nouadhibou
# Processing Record 22 of Set 1 | yerbogachen
# Processing Record 23 of Set 1 | west plains
# Processing Record 24 of Set 1 | qeshm
# Processing Record 25 of Set 1 | castro
# Processing Record 26 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 1 | mar del plata
# Processing Record 28 of Set 1 | ushuaia
# Processing Record 29 of Set 1 | chokurdakh
# Processing Record 30 of Set 1 | itacoatiara
# Processing Record 31 of Set 1 | nikolskoye
# Processing Record 32 of Set 1 | provideniya
# Processing Record 33 of Set 1 | saint-philippe
# Processing Record 34 of Set 1 | albany
# Processing Record 35 of Set 1 | avarua
# Processing Record 36 of Set 1 | kaitangata
# Processing Record 37 of Set 1 | moose factory
# Processing Record 38 of Set 1 | akdagmadeni
# Processing Record 39 of Set 1 | alofi
# Processing Record 40 of Set 1 | hermanus
# Processing Record 41 of Set 1 | isangel
# Processing Record 42 of Set 1 | qaanaaq
# Processing Record 43 of Set 1 | dikson
# Processing Record 44 of Set 1 | diepholz
# Processing Record 45 of Set 1 | mayo
# Processing Record 46 of Set 1 | christchurch
# Processing Record 47 of Set 1 | ribeira grande
# Processing Record 48 of Set 1 | madang
# Processing Record 49 of Set 1 | kodiak
# Processing Record 50 of Set 1 | grand gaube
# Processing Record 0 of Set 2 | cumana
# Processing Record 1 of Set 2 | rio grande
# Processing Record 2 of Set 2 | samarinda
# Processing Record 3 of Set 2 | ponta do sol
# Processing Record 4 of Set 2 | port alfred
# Processing Record 5 of Set 2 | esperance
# Processing Record 6 of Set 2 | sao miguel do araguaia
# Processing Record 7 of Set 2 | sinnamary
# Processing Record 8 of Set 2 | krapivinskiy
# Processing Record 9 of Set 2 | yako
# Processing Record 10 of Set 2 | soe
# Processing Record 11 of Set 2 | cape town
# Processing Record 12 of Set 2 | inhambane
# Processing Record 13 of Set 2 | manta
# Processing Record 14 of Set 2 | kapaa
# Processing Record 15 of Set 2 | ondangwa
# Processing Record 16 of Set 2 | hobart
# Processing Record 17 of Set 2 | kudahuvadhoo
# Processing Record 18 of Set 2 | alberton
# Processing Record 19 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 2 | cabo san lucas
# Processing Record 21 of Set 2 | quatre cocos
# Processing Record 22 of Set 2 | kampene
# Processing Record 23 of Set 2 | boden
# Processing Record 24 of Set 2 | sioux lookout
# Processing Record 25 of Set 2 | fortuna
# Processing Record 26 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 2 | puerto ayora
# Processing Record 28 of Set 2 | hokitika
# Processing Record 29 of Set 2 | salcininkai
# Processing Record 30 of Set 2 | lebu
# Processing Record 31 of Set 2 | margate
# Processing Record 32 of Set 2 | beloha
# Processing Record 33 of Set 2 | severo-kurilsk
# Processing Record 34 of Set 2 | taltal
# Processing Record 35 of Set 2 | kirkwall
# Processing Record 36 of Set 2 | touros
# Processing Record 37 of Set 2 | xining
# Processing Record 38 of Set 2 | wanning
# Processing Record 39 of Set 2 | yellowknife
# Processing Record 40 of Set 2 | jiddah
# City not found. Skipping...
# Processing Record 41 of Set 2 | punta arenas
# Processing Record 42 of Set 2 | cidreira
# Processing Record 43 of Set 2 | port hardy
# Processing Record 44 of Set 2 | preobrazheniye
# Processing Record 45 of Set 2 | tuatapere
# Processing Record 46 of Set 2 | mwene-ditu
# Processing Record 47 of Set 2 | pangnirtung
# Processing Record 48 of Set 2 | pyaozerskiy
# Processing Record 49 of Set 2 | la huerta
# Processing Record 50 of Set 2 | vila velha
# Processing Record 0 of Set 3 | arraial do cabo
# Processing Record 1 of Set 3 | boguchany
# Processing Record 2 of Set 3 | thompson
# Processing Record 3 of Set 3 | dmytrivka
# Processing Record 4 of Set 3 | bambous virieux
# Processing Record 5 of Set 3 | zavetnoye
# Processing Record 6 of Set 3 | bredasdorp
# Processing Record 7 of Set 3 | chernelytsya
# Processing Record 8 of Set 3 | big spring
# Processing Record 9 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 3 | ancud
# Processing Record 11 of Set 3 | busselton
# Processing Record 12 of Set 3 | satitoa
# City not found. Skipping...
# Processing Record 13 of Set 3 | la reforma
# Processing Record 14 of Set 3 | comodoro rivadavia
# Processing Record 15 of Set 3 | sao filipe
# Processing Record 16 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 3 | moranbah
# Processing Record 18 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 3 | carutapera
# Processing Record 20 of Set 3 | cartagena del chaira
# Processing Record 21 of Set 3 | atuona
# Processing Record 22 of Set 3 | tasiilaq
# Processing Record 23 of Set 3 | vrangel
# Processing Record 24 of Set 3 | wilmington
# Processing Record 25 of Set 3 | faanui
# Processing Record 26 of Set 3 | georgetown
# Processing Record 27 of Set 3 | lavrentiya
# Processing Record 28 of Set 3 | bethel
# Processing Record 29 of Set 3 | holetown
# Processing Record 30 of Set 3 | hanzhong
# Processing Record 31 of Set 3 | tornio
# Processing Record 32 of Set 3 | dudinka
# Processing Record 33 of Set 3 | east london
# Processing Record 34 of Set 3 | gat
# Processing Record 35 of Set 3 | tarudant
# City not found. Skipping...
# Processing Record 36 of Set 3 | dzilam gonzalez
# Processing Record 37 of Set 3 | upernavik
# Processing Record 38 of Set 3 | hithadhoo
# Processing Record 39 of Set 3 | geraldton
# Processing Record 40 of Set 3 | lompoc
# Processing Record 41 of Set 3 | richards bay
# Processing Record 42 of Set 3 | victoria
# Processing Record 43 of Set 3 | saint george
# Processing Record 44 of Set 3 | cam pha
# City not found. Skipping...
# Processing Record 45 of Set 3 | kouroussa
# Processing Record 46 of Set 3 | souillac
# Processing Record 47 of Set 3 | san cristobal
# Processing Record 48 of Set 3 | sai buri
# Processing Record 49 of Set 3 | marienburg
# Processing Record 50 of Set 3 | sept-iles
# Processing Record 0 of Set 4 | dingle
# Processing Record 1 of Set 4 | damaturu
# Processing Record 2 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 4 | saint anthony
# Processing Record 4 of Set 4 | jian
# Processing Record 5 of Set 4 | raga
# Processing Record 6 of Set 4 | worthington
# Processing Record 7 of Set 4 | hunza
# City not found. Skipping...
# Processing Record 8 of Set 4 | klaksvik
# Processing Record 9 of Set 4 | honiara
# Processing Record 10 of Set 4 | andros town
# Processing Record 11 of Set 4 | bakchar
# Processing Record 12 of Set 4 | tuktoyaktuk
# Processing Record 13 of Set 4 | nacimiento
# Processing Record 14 of Set 4 | meulaboh
# Processing Record 15 of Set 4 | hilo
# Processing Record 16 of Set 4 | iqaluit
# Processing Record 17 of Set 4 | butaritari
# Processing Record 18 of Set 4 | leningradskiy
# Processing Record 19 of Set 4 | vila do maio
# Processing Record 20 of Set 4 | khatanga
# Processing Record 21 of Set 4 | the valley
# Processing Record 22 of Set 4 | praia da vitoria
# Processing Record 23 of Set 4 | melfi
# Processing Record 24 of Set 4 | saskylakh
# Processing Record 25 of Set 4 | victoria point
# Processing Record 26 of Set 4 | mende
# Processing Record 27 of Set 4 | cayenne
# Processing Record 28 of Set 4 | ozernovskiy
# Processing Record 29 of Set 4 | saint-pierre
# Processing Record 30 of Set 4 | mackay
# Processing Record 31 of Set 4 | longyearbyen
# Processing Record 32 of Set 4 | solnechnyy
# Processing Record 33 of Set 4 | zhanatas
# City not found. Skipping...
# Processing Record 34 of Set 4 | port moresby
# Processing Record 35 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 4 | jinchang
# Processing Record 37 of Set 4 | airai
# Processing Record 38 of Set 4 | gorontalo
# Processing Record 39 of Set 4 | muli
# Processing Record 40 of Set 4 | port-gentil
# Processing Record 41 of Set 4 | coquimbo
# Processing Record 42 of Set 4 | kaduqli
# Processing Record 43 of Set 4 | inderborskiy
# City not found. Skipping...
# Processing Record 44 of Set 4 | bambari
# Processing Record 45 of Set 4 | tapaua
# City not found. Skipping...
# Processing Record 46 of Set 4 | tayshet
# Processing Record 47 of Set 4 | mae sai
# Processing Record 48 of Set 4 | lasa
# Processing Record 49 of Set 4 | lakatoro
# Processing Record 50 of Set 4 | kaeo
# Processing Record 0 of Set 5 | sobolevo
# Processing Record 1 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 2 of Set 5 | artesia
# Processing Record 3 of Set 5 | araouane
# Processing Record 4 of Set 5 | khandbari
# Processing Record 5 of Set 5 | gambo
# Processing Record 6 of Set 5 | methven
# Processing Record 7 of Set 5 | vila franca do campo
# Processing Record 8 of Set 5 | eureka
# Processing Record 9 of Set 5 | puerto escondido
# Processing Record 10 of Set 5 | los llanos de aridane
# Processing Record 11 of Set 5 | norman wells
# Processing Record 12 of Set 5 | kashi
# Processing Record 13 of Set 5 | garowe
# Processing Record 14 of Set 5 | olga
# Processing Record 15 of Set 5 | bushehr
# Processing Record 16 of Set 5 | leh
# Processing Record 17 of Set 5 | tikhvin
# Processing Record 18 of Set 5 | powell river
# Processing Record 19 of Set 5 | tromso
# Processing Record 20 of Set 5 | umm durman
# City not found. Skipping...
# Processing Record 21 of Set 5 | pangai
# Processing Record 22 of Set 5 | goderich
# Processing Record 23 of Set 5 | lorengau
# Processing Record 24 of Set 5 | yulara
# Processing Record 25 of Set 5 | guerrero negro
# Processing Record 26 of Set 5 | taicheng
# Processing Record 27 of Set 5 | la ciotat
# Processing Record 28 of Set 5 | chara
# Processing Record 29 of Set 5 | riverton
# Processing Record 30 of Set 5 | taoudenni
# Processing Record 31 of Set 5 | livingston
# Processing Record 32 of Set 5 | bengkulu
# Processing Record 33 of Set 5 | harper
# Processing Record 34 of Set 5 | dera din panah
# City not found. Skipping...
# Processing Record 35 of Set 5 | vysokogornyy
# Processing Record 36 of Set 5 | rosarito
# Processing Record 37 of Set 5 | goure
# Processing Record 38 of Set 5 | vila
# Processing Record 39 of Set 5 | whitehorse
# Processing Record 40 of Set 5 | vestmanna
# Processing Record 41 of Set 5 | cap malheureux
# Processing Record 42 of Set 5 | gulshat
# City not found. Skipping...
# Processing Record 43 of Set 5 | amboise
# Processing Record 44 of Set 5 | changde
# Processing Record 45 of Set 5 | helong
# Processing Record 46 of Set 5 | hamilton
# Processing Record 47 of Set 5 | hofn
# Processing Record 48 of Set 5 | barrow
# Processing Record 49 of Set 5 | norsup
# Processing Record 50 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 0 of Set 6 | lima
# Processing Record 1 of Set 6 | inirida
# Processing Record 2 of Set 6 | ca mau
# Processing Record 3 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 4 of Set 6 | jamestown
# Processing Record 5 of Set 6 | novyy yarychiv
# Processing Record 6 of Set 6 | ramsar
# Processing Record 7 of Set 6 | rengo
# Processing Record 8 of Set 6 | puruliya
# Processing Record 9 of Set 6 | burnie
# Processing Record 10 of Set 6 | codrington
# Processing Record 11 of Set 6 | hasaki
# Processing Record 12 of Set 6 | dargaville
# Processing Record 13 of Set 6 | waddan
# Processing Record 14 of Set 6 | nenjiang
# Processing Record 15 of Set 6 | sindor
# Processing Record 16 of Set 6 | naples
# Processing Record 17 of Set 6 | ahipara
# Processing Record 18 of Set 6 | manyana
# Processing Record 19 of Set 6 | sunbury
# Processing Record 20 of Set 6 | kruisfontein
# Processing Record 21 of Set 6 | lantawan
# Processing Record 22 of Set 6 | cabedelo
# Processing Record 23 of Set 6 | esna
# Processing Record 24 of Set 6 | newport
# Processing Record 25 of Set 6 | lodja
# Processing Record 26 of Set 6 | komsomolskiy
# Processing Record 27 of Set 6 | aldan
# Processing Record 28 of Set 6 | shingu
# Processing Record 29 of Set 6 | monywa
# Processing Record 30 of Set 6 | qiongshan
# Processing Record 31 of Set 6 | abu dhabi
# Processing Record 32 of Set 6 | csomor
# Processing Record 33 of Set 6 | port shepstone
# Processing Record 34 of Set 6 | luan
# Processing Record 35 of Set 6 | kstovo
# Processing Record 36 of Set 6 | makakilo city
# Processing Record 37 of Set 6 | constitucion
# Processing Record 38 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 39 of Set 6 | morehead
# Processing Record 40 of Set 6 | pavlodar
# Processing Record 41 of Set 6 | makaha
# Processing Record 42 of Set 6 | kahama
# Processing Record 43 of Set 6 | caravelas
# Processing Record 44 of Set 6 | salamanca
# Processing Record 45 of Set 6 | san patricio
# Processing Record 46 of Set 6 | jalu
# Processing Record 47 of Set 6 | nanchang
# Processing Record 48 of Set 6 | pevek
# Processing Record 49 of Set 6 | samarai
# Processing Record 50 of Set 6 | alta floresta
# Processing Record 0 of Set 7 | sao felix do xingu
# Processing Record 1 of Set 7 | rawson
# Processing Record 2 of Set 7 | tessalit
# Processing Record 3 of Set 7 | katsuura
# Processing Record 4 of Set 7 | flinders
# Processing Record 5 of Set 7 | carnarvon
# Processing Record 6 of Set 7 | oum hadjer
# Processing Record 7 of Set 7 | stephenville crossing
# Processing Record 8 of Set 7 | avera
# Processing Record 9 of Set 7 | alappuzha
# Processing Record 10 of Set 7 | san lazaro
# Processing Record 11 of Set 7 | mojoagung
# Processing Record 12 of Set 7 | cherskiy
# Processing Record 13 of Set 7 | anito
# Processing Record 14 of Set 7 | mentok
# City not found. Skipping...
# Processing Record 15 of Set 7 | teneguiban
# City not found. Skipping...
# Processing Record 16 of Set 7 | arlit
# Processing Record 17 of Set 7 | marsa matruh
# Processing Record 18 of Set 7 | mount darwin
# Processing Record 19 of Set 7 | kalispell
# Processing Record 20 of Set 7 | neuquen
# Processing Record 21 of Set 7 | saldanha
# Processing Record 22 of Set 7 | sao joao da barra
# Processing Record 23 of Set 7 | itarema
# Processing Record 24 of Set 7 | vostok
# Processing Record 25 of Set 7 | hakkari
# Processing Record 26 of Set 7 | te anau
# Processing Record 27 of Set 7 | omboue
# Processing Record 28 of Set 7 | acarau
# Processing Record 29 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 30 of Set 7 | aasiaat
# Processing Record 31 of Set 7 | freudenstadt
# Processing Record 32 of Set 7 | ixtapa
# Processing Record 33 of Set 7 | peleduy
# Processing Record 34 of Set 7 | kalga
# Processing Record 35 of Set 7 | santa catalina
# Processing Record 36 of Set 7 | zhigalovo
# Processing Record 37 of Set 7 | saint-leu
# Processing Record 38 of Set 7 | pereslavl-zalesskiy
# Processing Record 39 of Set 7 | nowy sacz
# Processing Record 40 of Set 7 | kavaratti
# Processing Record 41 of Set 7 | bentiu
# Processing Record 42 of Set 7 | betafo
# Processing Record 43 of Set 7 | chor
# Processing Record 44 of Set 7 | eyl
# Processing Record 45 of Set 7 | camana
# Processing Record 46 of Set 7 | parkes
# Processing Record 47 of Set 7 | sipe sipe
# Processing Record 48 of Set 7 | henties bay
# Processing Record 49 of Set 7 | kerouane
# Processing Record 50 of Set 7 | mlonggo
# Processing Record 0 of Set 8 | harrison
# Processing Record 1 of Set 8 | port hedland
# Processing Record 2 of Set 8 | mitsamiouli
# Processing Record 3 of Set 8 | buala
# Processing Record 4 of Set 8 | namatanai
# Processing Record 5 of Set 8 | laguna de perlas
# Processing Record 6 of Set 8 | marawi
# Processing Record 7 of Set 8 | adeje
# Processing Record 8 of Set 8 | novo aripuana
# Processing Record 9 of Set 8 | tateyama
# Processing Record 10 of Set 8 | berlevag
# Processing Record 11 of Set 8 | beidao
# Processing Record 12 of Set 8 | birnin kebbi
# Processing Record 13 of Set 8 | cape elizabeth
# City not found. Skipping...
# Processing Record 14 of Set 8 | bulalacao
# Processing Record 15 of Set 8 | kirakira
# Processing Record 16 of Set 8 | katangli
# Processing Record 17 of Set 8 | at-bashi
# Processing Record 18 of Set 8 | kasane
# Processing Record 19 of Set 8 | nome
# Processing Record 20 of Set 8 | hirara
# Processing Record 21 of Set 8 | pastavy
# Processing Record 22 of Set 8 | mithimna
# City not found. Skipping...
# Processing Record 23 of Set 8 | cao bang
# Processing Record 24 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 8 | nabire
# Processing Record 26 of Set 8 | beringovskiy
# Processing Record 27 of Set 8 | bayanday
# Processing Record 28 of Set 8 | pacific grove
# Processing Record 29 of Set 8 | terrace bay
# Processing Record 30 of Set 8 | malpe
# Processing Record 31 of Set 8 | yakeshi
# Processing Record 32 of Set 8 | meridian
# Processing Record 33 of Set 8 | mwinilunga
# Processing Record 34 of Set 8 | wadi maliz
# Processing Record 35 of Set 8 | broken hill
# Processing Record 36 of Set 8 | vung tau
# Processing Record 37 of Set 8 | sohag
# Processing Record 38 of Set 8 | necochea
# Processing Record 39 of Set 8 | broome
# Processing Record 40 of Set 8 | aklavik
# Processing Record 41 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 8 | teberda
# Processing Record 43 of Set 8 | takoradi
# Processing Record 44 of Set 8 | amberley
# Processing Record 45 of Set 8 | alice springs
# Processing Record 46 of Set 8 | emba
# Processing Record 47 of Set 8 | camacupa
# Processing Record 48 of Set 8 | tura
# Processing Record 49 of Set 8 | skjervoy
# Processing Record 50 of Set 8 | windhoek
# Processing Record 0 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 9 | madimba
# Processing Record 2 of Set 9 | kribi
# Processing Record 3 of Set 9 | tautira
# Processing Record 4 of Set 9 | gravdal
# Processing Record 5 of Set 9 | pendleton
# Processing Record 6 of Set 9 | kidal
# Processing Record 7 of Set 9 | rocha
# Processing Record 8 of Set 9 | gambela
# Processing Record 9 of Set 9 | craig
# Processing Record 10 of Set 9 | seguela
# Processing Record 11 of Set 9 | la ronge
# Processing Record 12 of Set 9 | santa cruz de tenerife
# Processing Record 13 of Set 9 | ostrovnoy
# Processing Record 14 of Set 9 | altay
# Processing Record 15 of Set 9 | tanjong malim
# City not found. Skipping...
# Processing Record 16 of Set 9 | kaputa
# Processing Record 17 of Set 9 | saryozek
# Processing Record 18 of Set 9 | evensk
# Processing Record 19 of Set 9 | jiuquan
# Processing Record 20 of Set 9 | orda
# Processing Record 21 of Set 9 | lashio
# Processing Record 22 of Set 9 | saint-augustin
# Processing Record 23 of Set 9 | balkanabat
# Processing Record 24 of Set 9 | rapar
# Processing Record 25 of Set 9 | tiksi
# Processing Record 26 of Set 9 | loandjili
# Processing Record 27 of Set 9 | emirdag
# Processing Record 28 of Set 9 | gorbanesti
# Processing Record 29 of Set 9 | natalio
# Processing Record 30 of Set 9 | ichikawa
# Processing Record 31 of Set 9 | marrakesh
# Processing Record 32 of Set 9 | kieta
# Processing Record 33 of Set 9 | golden
# Processing Record 34 of Set 9 | keuruu
# Processing Record 35 of Set 9 | fengzhen
# Processing Record 36 of Set 9 | koslan
# Processing Record 37 of Set 9 | idenao
# Processing Record 38 of Set 9 | ilulissat
# Processing Record 39 of Set 9 | marzuq
# Processing Record 40 of Set 9 | brest
# Processing Record 41 of Set 9 | concepcion del oro
# Processing Record 42 of Set 9 | inta
# Processing Record 43 of Set 9 | champerico
# Processing Record 44 of Set 9 | mayumba
# Processing Record 45 of Set 9 | novikovo
# Processing Record 46 of Set 9 | wewak
# Processing Record 47 of Set 9 | messina
# Processing Record 48 of Set 9 | sur
# Processing Record 49 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 50 of Set 9 | sainte-rose
# Processing Record 0 of Set 10 | pensacola
# Processing Record 1 of Set 10 | egvekinot
# Processing Record 2 of Set 10 | northam
# Processing Record 3 of Set 10 | balaguer
# Processing Record 4 of Set 10 | ucluelet
# Processing Record 5 of Set 10 | masvingo
# Processing Record 6 of Set 10 | srednekolymsk
# Processing Record 7 of Set 10 | trincomalee
# Processing Record 8 of Set 10 | presidente olegario
# Processing Record 9 of Set 10 | sabha
# Processing Record 10 of Set 10 | nicolas bravo
# Processing Record 11 of Set 10 | tual
# Processing Record 12 of Set 10 | filadelfia
# Processing Record 13 of Set 10 | zhanaozen
# Processing Record 14 of Set 10 | pijijiapan
# Processing Record 15 of Set 10 | enid
# Processing Record 16 of Set 10 | san rafael
# Processing Record 17 of Set 10 | sao paulo de olivenca
# Processing Record 18 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 10 | ustrzyki dolne
# Processing Record 20 of Set 10 | gurskoye
# City not found. Skipping...
# Processing Record 21 of Set 10 | pringsewu
# Processing Record 22 of Set 10 | krasnooktyabrskiy
# Processing Record 23 of Set 10 | belyy yar
# Processing Record 24 of Set 10 | rio gallegos
# Processing Record 25 of Set 10 | qaqortoq
# Processing Record 26 of Set 10 | husavik
# Processing Record 27 of Set 10 | naze
# Processing Record 28 of Set 10 | winslow
# Processing Record 29 of Set 10 | baijiantan
# Processing Record 30 of Set 10 | shkotovo-26
# City not found. Skipping...
# Processing Record 31 of Set 10 | mecca
# Processing Record 32 of Set 10 | talavera de la reina
# Processing Record 33 of Set 10 | almaty
# Processing Record 34 of Set 10 | hami
# Processing Record 35 of Set 10 | maceio
# Processing Record 36 of Set 10 | vao
# Processing Record 37 of Set 10 | hyeres
# Processing Record 38 of Set 10 | hovd
# Processing Record 39 of Set 10 | westpunt
# City not found. Skipping...
# Processing Record 40 of Set 10 | weston
# Processing Record 41 of Set 10 | ankara
# Processing Record 42 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 43 of Set 10 | pahrump
# Processing Record 44 of Set 10 | dinghai
# Processing Record 45 of Set 10 | semnan
# Processing Record 46 of Set 10 | south sioux city
# Processing Record 47 of Set 10 | narsaq
# Processing Record 48 of Set 10 | college
# Processing Record 49 of Set 10 | nerchinskiy zavod
# Processing Record 50 of Set 10 | nachod
# Processing Record 0 of Set 11 | kununurra
# Processing Record 1 of Set 11 | pleasant point
# Processing Record 2 of Set 11 | ust-kalmanka
# Processing Record 3 of Set 11 | san quintin
# Processing Record 4 of Set 11 | cockburn town
# Processing Record 5 of Set 11 | virginia beach
# Processing Record 6 of Set 11 | wakefield
# Processing Record 7 of Set 11 | bathsheba
# Processing Record 8 of Set 11 | yagodnoye
# Processing Record 9 of Set 11 | kesova gora
# Processing Record 10 of Set 11 | alghero
# Processing Record 11 of Set 11 | never
# Processing Record 12 of Set 11 | aketi
# Processing Record 13 of Set 11 | pizarro
# Processing Record 14 of Set 11 | awjilah
# Processing Record 15 of Set 11 | dallas
# Processing Record 16 of Set 11 | salalah
# Processing Record 17 of Set 11 | santa rosalia
# Processing Record 18 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 19 of Set 11 | kismayo
# Processing Record 20 of Set 11 | tilichiki
# Processing Record 21 of Set 11 | dauriya
# Processing Record 22 of Set 11 | constantine
# Processing Record 23 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 11 | san bernardo
# Processing Record 26 of Set 11 | masuguru
# Processing Record 27 of Set 11 | merauke
# Processing Record 28 of Set 11 | dakar
# Processing Record 29 of Set 11 | mandan
# Processing Record 30 of Set 11 | nantucket
# Processing Record 31 of Set 11 | mahon
# Processing Record 32 of Set 11 | porto uniao
# Processing Record 33 of Set 11 | alexandria
# Processing Record 34 of Set 11 | kuito
# Processing Record 35 of Set 11 | griffith
# Processing Record 36 of Set 11 | nefteyugansk
# Processing Record 37 of Set 11 | zanjan
# Processing Record 38 of Set 11 | lata
# Processing Record 39 of Set 11 | puro
# Processing Record 40 of Set 11 | turinskaya sloboda
# Processing Record 41 of Set 11 | brainerd
# Processing Record 42 of Set 11 | mollendo
# Processing Record 43 of Set 11 | macas
# Processing Record 44 of Set 11 | sisimiut
# Processing Record 45 of Set 11 | minbu
# Processing Record 46 of Set 11 | chifeng
# Processing Record 47 of Set 11 | poum
# Processing Record 48 of Set 11 | kendari
# Processing Record 49 of Set 11 | general roca
# Processing Record 50 of Set 11 | matamoros
# Processing Record 0 of Set 12 | krasnoye
# Processing Record 1 of Set 12 | timbiqui
# Processing Record 2 of Set 12 | yar-sale
# Processing Record 3 of Set 12 | kangaatsiaq
# Processing Record 4 of Set 12 | carauari
# Processing Record 5 of Set 12 | imperatriz
# Processing Record 6 of Set 12 | porto novo
# Processing Record 7 of Set 12 | acajutla
# Processing Record 8 of Set 12 | asau
# Processing Record 9 of Set 12 | villazon
# Processing Record 10 of Set 12 | galle
# Processing Record 11 of Set 12 | llanes
# Processing Record 12 of Set 12 | belen
# Processing Record 13 of Set 12 | ribeira brava
# Processing Record 14 of Set 12 | baykit
# Processing Record 15 of Set 12 | klyuchi
# Processing Record 16 of Set 12 | morococha
# Processing Record 17 of Set 12 | machali
# Processing Record 18 of Set 12 | kitwe
# Processing Record 19 of Set 12 | litoral del san juan
# City not found. Skipping...
# Processing Record 20 of Set 12 | wysokie mazowieckie
# Processing Record 21 of Set 12 | marsh harbour
# Processing Record 22 of Set 12 | anadyr
# Processing Record 23 of Set 12 | teguldet
# Processing Record 24 of Set 12 | atherton
# Processing Record 25 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 26 of Set 12 | mandurah
# Processing Record 27 of Set 12 | axim
# Processing Record 28 of Set 12 | prince rupert
# Processing Record 29 of Set 12 | nanortalik
# Processing Record 30 of Set 12 | boyolangu
# Processing Record 31 of Set 12 | gamba
# Processing Record 32 of Set 12 | laguna
# Processing Record 33 of Set 12 | koumac
# Processing Record 34 of Set 12 | north augusta
# Processing Record 35 of Set 12 | biak
# Processing Record 36 of Set 12 | chadan
# Processing Record 37 of Set 12 | anupgarh
# Processing Record 38 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 39 of Set 12 | batemans bay
# Processing Record 40 of Set 12 | libenge
# Processing Record 41 of Set 12 | puerto del rosario
# Processing Record 42 of Set 12 | turbat
# Processing Record 43 of Set 12 | mandalgovi
# Processing Record 44 of Set 12 | rudnichnyy
# Processing Record 45 of Set 12 | blagoyevo
# Processing Record 46 of Set 12 | port augusta
# Processing Record 47 of Set 12 | sorland
# Processing Record 48 of Set 12 | caxito
# Processing Record 49 of Set 12 | half moon bay
# Processing Record 50 of Set 12 | lat yao
# Processing Record 0 of Set 13 | hearst
# Processing Record 1 of Set 13 | izhma
# Processing Record 2 of Set 13 | mount gambier
# Processing Record 3 of Set 13 | mehamn
# Processing Record 4 of Set 13 | weihe
# Processing Record 5 of Set 13 | springfield
# Processing Record 6 of Set 13 | ouahigouya
# Processing Record 7 of Set 13 | beira
# Processing Record 8 of Set 13 | kalengwa
# Processing Record 9 of Set 13 | viedma
# Processing Record 10 of Set 13 | buraydah
# Processing Record 11 of Set 13 | slave lake
# Processing Record 12 of Set 13 | roald
# Processing Record 13 of Set 13 | vaitape
# Processing Record 14 of Set 13 | gardez
# Processing Record 15 of Set 13 | puri
# Processing Record 16 of Set 13 | karratha
# Processing Record 17 of Set 13 | yabrud
# Processing Record 18 of Set 13 | terrace
# Processing Record 19 of Set 13 | nhamunda
# Processing Record 20 of Set 13 | mount isa
# Processing Record 21 of Set 13 | vanderhoof
# Processing Record 22 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 23 of Set 13 | wagar
# Processing Record 24 of Set 13 | jiaocheng
# Processing Record 25 of Set 13 | xiuyan
# Processing Record 26 of Set 13 | yomitan
# City not found. Skipping...
# Processing Record 27 of Set 13 | sunrise manor
# Processing Record 28 of Set 13 | westport
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# order dic columns as show in example
weather_dict=({
    'City':city_list,
    'Latitude':lat_list,
    'Longitude':lng_list,
    'Max Temp':max_temp_list,
    'Humidity':humidity_list,
    'Cloudiness':cloudiness_list,
    'Wind Speed':wind_speed_list,
    'Country':country_list,
    'Date':date_list
})
weather_df=pd.DataFrame(weather_dict)

weather_df
# Out:
#                City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0             Pisco  -13.7000   -76.2167     70.00        83          40
# 1      Port Lincoln  -34.7333   135.8667     75.99        49          19
# 2             Bluff  -46.6000   168.3333     53.89        83         100
# 3    Port Elizabeth  -33.9180    25.5701     73.40        64           0
# 4             Vaini  -21.2000  -175.2000     77.00       100          90
# ..              ...       ...        ...       ...       ...         ...
# 586           Wagar   16.1525    36.2032     71.08        62           0
# 587       Jiaocheng   24.6774   116.1389     63.48        69         100
# 588          Xiuyan   40.2928   123.2744     40.68        62           0
# 589   Sunrise Manor   36.2111  -115.0731     59.00        23          75
# 590        Westport   41.1415   -73.3579     24.80        58          20
#
#      Wind Speed Country        Date
# 0          2.30      PE  1612850231
# 1          8.39      AU  1612850292
# 2         11.92      NZ  1612850292
# 3          2.30      ZA  1612850292
# 4         20.71      TO  1612850236
# ..          ...     ...         ...
# 586        9.08      SD  1612850392
# 587        4.23      CN  1612850392
# 588        5.30      CN  1612850392
# 589        9.22      US  1612850173
# 590        3.44      US  1612850248
#
# [591 rows x 9 columns]

# %%
# use describe to produce summary statistics
weather_df.describe()
# Out:
#          Latitude   Longitude    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  564.000000  564.000000  564.000000  564.000000  564.000000  564.000000
# mean    19.784652   12.703756   52.062340   71.897163   51.732270    8.184220
# std     32.752379   87.834367   30.529612   21.058830   40.037029    5.564629
# min    -54.800000 -179.166700  -45.400000   13.000000    0.000000    0.220000
# 25%     -7.122600  -65.254850   33.795000   62.000000    3.750000    4.102500
# 50%     22.591500   19.175600   61.025000   78.000000   50.000000    6.910000
# 75%     46.658275   80.299125   76.627500   87.000000   90.250000   10.987500
# max     78.218600  178.416700   95.340000  100.000000  100.000000   31.070000
#
#                Date
# count  5.640000e+02
# mean   1.612507e+09
# std    6.633503e+01
# min    1.612507e+09
# 25%    1.612507e+09
# 50%    1.612507e+09
# 75%    1.612507e+09
# max    1.612507e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# use describe to produce summary statistics
weather_df.describe()
# Out:
#          Latitude   Longitude    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  591.000000  591.000000  591.000000  591.000000  591.000000  591.000000
# mean    19.779741   18.034042   49.850288   73.397631   55.186125    8.152809
# std     32.897760   89.977361   30.768198   20.637450   38.702374    6.173703
# min    -54.800000 -179.166700  -43.600000   10.000000    0.000000    0.250000
# 25%     -6.932750  -63.561600   28.545000   64.000000   19.000000    3.490000
# 50%     25.519800   22.263300   59.000000   79.000000   65.000000    6.670000
# 75%     46.908150   97.601550   75.000000   88.000000   92.500000   11.160000
# max     78.218600  179.316700  102.200000  100.000000  100.000000   39.120000
#
#                Date
# count  5.910000e+02
# mean   1.612850e+09
# std    5.819959e+01
# min    1.612850e+09
# 25%    1.612850e+09
# 50%    1.612850e+09
# 75%    1.612850e+09
# max    1.612850e+09

# %%
#  Get the indices of cities that have humidity over 100%.
outliers_df=weather_df[weather_df['Humidity']>=99.9]
outliers_df
# Out:
#                         City  Latitude  Longitude  Max Temp  Humidity  \
# 4                      Vaini  -21.2000  -175.2000     77.00       100
# 163  Arrondissement de Mende   44.6667     3.5000     31.59       100
# 190     Vila Franca do Campo   37.7167   -25.4333     60.01       100
# 273             San Patricio   28.0170   -97.5169     69.01       100
# 302         Hakkâri Province   37.5833    44.1667     12.20       100
# 344                   Kasane  -17.8167    25.1500     68.00       100
# 409                   Idenao    4.2475     9.0047     80.60       100
# 425                 Balaguer   41.7912     0.8109     42.01       100
# 430      Presidente Olegário  -18.4178   -46.4181     60.01       100
# 446                  Husavik   66.0449   -17.3389     28.40       100
# 458                   Weston   26.1004   -80.3998     72.00       100
# 528                    Belen   36.4891    36.2233     48.20       100
# 569              Springfield   37.2153   -93.2982     23.00       100
# 574                 Buraidah   26.3260    43.9750     42.80       100
#
#      Cloudiness  Wind Speed Country        Date
# 4            90       20.71      TO  1612850236
# 163         100        4.72      FR  1612850321
# 190          75       18.41      PT  1612850303
# 273          90        4.61      US  1612850340
# 302          90        2.30      TR  1612850345
# 344          75        9.22      BW  1612850352
# 409          20        8.05      CM  1612850363
# 425           0        6.91      ES  1612850366
# 430          16        1.74      BR  1612850367
# 446          90        3.44      IS  1612850369
# 458          20        1.59      US  1612850372
# 528          16        4.61      TR  1612850383
# 569          90       11.50      US  1612850389
# 574           0        2.59      SA  1612850390

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data=weather_df.drop(weather_df[weather_df['Humidity']>=99.9].index,inplace=False)
sorted_clean_city=clean_city_data.sort_values(by=['City'],ascending=True)
sorted_clean_city.head(10)
# Out:
#             City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 306      Aasiaat   68.7098   -52.8699     14.04        88           0
# 260    Abu Dhabi   24.4667    54.3667     69.80        73           0
# 523     Acajutla   13.5928   -89.8275     76.89        80          22
# 305       Acaraú   -2.8856   -40.1200     78.28        86          94
# 334        Adeje   28.1227   -16.7260     62.01        77          40
# 246      Ahipara  -35.1667   173.1667     69.78        80          98
# 172        Airai   -8.9266   125.4092     70.57        90         100
# 33   Akdağmadeni   39.6603    35.8836     42.24        62          71
# 480        Aketi    2.7388    23.7833     69.46        40         100
# 364      Aklavik   68.2191  -135.0107    -40.00        74          42
#
#      Wind Speed Country        Date
# 306        9.26      GL  1612850346
# 260        6.91      AE  1612850269
# 523        6.73      SV  1612850382
# 305        7.45      BR  1612850059
# 334        8.05      ES  1612850237
# 246       11.43      NZ  1612850336
# 172        5.35      TL  1612850323
# 33         9.37      TR  1612850297
# 480        1.72      CD  1612850375
# 364        3.44      CA  1612850255

# %%
weather_time=weather_df
weather_time=pd.to_datetime(weather_time['Date'],unit='s')
weather_time.head(1)
# Out:
# 0   2021-02-09 05:57:11
# Name: Date, dtype: datetime64[ns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#Latitude vs. Temperature Plot
weather_df.plot(kind='scatter',x="Latitude",y='Max Temp',c='dodgerblue',edgecolor='black',alpha=.5)
#add headers and axis labels
plt.title('Latitude V Max Temperature - 2/09/2021')
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
#add grid lines
plt.grid()

#save figure
plt.savefig('../Images/LatvMaxTemp.png')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#Latitude vs. Humidity Plot
weather_df.plot(kind='scatter',x="Latitude",y='Humidity',c='dodgerblue',edgecolor='black',alpha=.5)
#add headers and axis labels
plt.title('Latitude V Humidity - 2/09/2021')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
#add grid lines
plt.grid()

#save figure
plt.savefig('../Images/LatvHumidity.png')

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#Latitude vs. Cloudiness Plot
weather_df.plot(kind='scatter',x="Latitude",y='Cloudiness',c='dodgerblue',edgecolor='black',alpha=.5)
#add headers and axis labels
plt.title('Latitude V Cloudiness - 2/09/2021')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
#add grid lines
plt.grid()

#save figure
plt.savefig('../Images/LatvCloudiness.png')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#Latitude vs. Wind SpeedPlot
weather_df.plot(kind='scatter',x="Latitude",y='Wind Speed',c='dodgerblue',edgecolor='black',alpha=.5)
#add headers and axis labels
plt.title('Latitude V Wind Speed - 2/09/2021')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
#add grid lines
plt.grid()

#save figure
plt.savefig('../Images/LatvWind Speed.png')

# %% [markdown]
# ## Linear Regression

# %%
#create dataframes for the northern and souther hemisphere to use during linear regression
northern_df=weather_df.loc[weather_df['Latitude']>=0]
southern_df=weather_df.loc[weather_df['Latitude']<0]

# %%
#import linregress to use throughout the rest of the code
from scipy.stats import linregress

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#set values to plot
x_values = northern_df['Latitude']
y_values = northern_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

#set title, xlabel, and ylabel
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
# print rvalue,line_eq 
print(f"The r value is: {round(rvalue,2)}")
print(f"The linear equation is:{line_eq}")
plt.savefig('../Images/LR_NH_LatVMaxTemp.png')
# Out:
# The r value is: -0.87
# The linear equation is:y = -1.41x + 93.12

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#set values to plot
x_values = southern_df['Latitude']
y_values = southern_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

#set title, xlabel, and ylabel
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Max Temp')

# print rvalue,line_eq 
print(f"The r value is: {round(rvalue,2)}")
print(f"The linear equation is:{line_eq}")
plt.savefig('../Images/LR_SH_LatVMaxTemp.png')
# Out:
# The r value is: 0.51
# The linear equation is:y = 0.39x + 82.0

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#set values to plot
x_values = northern_df['Latitude']
y_values = northern_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

#set title, xlabel, and ylabel
plt.title('Northern Hemisphere - Humidity(%) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Humidity')

# print rvalue,line_eq 
print(f"The r value is: {round(rvalue,2)}")
print(f"The linear equation is:{line_eq}")
plt.savefig('../Images/LR_NH_LatVHumidity.png')
# Out:
# The r value is: 0.34
# The linear equation is:y = 0.4x + 56.77

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#set values to plot
x_values = southern_df['Latitude']
y_values = southern_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

#set title, xlabel, and ylabel
plt.title('Southern Hemisphere - Humidity(%) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Humidity')

# print rvalue,line_eq 
print(f"The r value is: {round(rvalue,2)}")
print(f"The linear equation is:{line_eq}")
plt.savefig('../Images/LR_SH_LatVHumidity.png')
# Out:
# The r value is: 0.26
# The linear equation is:y = 0.32x + 83.06

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#set values to plot
x_values = northern_df['Latitude']
y_values = northern_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

#set title, xlabel, and ylabel
plt.title('Northern Hemisphere - Cloudiness(%) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

# print rvalue,line_eq 
print(f"The r value is: {round(rvalue,2)}")
print(f"The linear equation is:{line_eq}")
plt.savefig('../Images/LR_NH_LatVCloudiness.png')
# Out:
# The r value is: 0.1
# The linear equation is:y = 0.21x + 45.47

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#set values to plot
x_values = southern_df['Latitude']
y_values = southern_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

#set title, xlabel, and ylabel
plt.title('Southern Hemisphere - Cloudiness(%) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

# print rvalue,line_eq 
print(f"The r value is: {round(rvalue,2)}")
print(f"The linear equation is:{line_eq}")
plt.savefig('../Images/LR_SH_LatVCloudiness.png')
# Out:
# The r value is: 0.42
# The linear equation is:y = 1.18x + 83.58

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#set values to plot
x_values = northern_df['Latitude']
y_values = northern_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

#set title, xlabel, and ylabel
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')

# print rvalue,line_eq 
print(f"The r value is: {round(rvalue,2)}")
print(f"The linear equation is:{line_eq}")
plt.savefig('../Images/LR_NH_LatVWindSpeed.png')
# Out:
# The r value is: 0.08
# The linear equation is:y = 0.03x + 7.4

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#set values to plot
x_values = southern_df['Latitude']
y_values = southern_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

#set title, xlabel, and ylabel
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')

# print rvalue,line_eq 
print(f"The r value is: {round(rvalue,2)}")
print(f"The linear equation is:{line_eq}")
plt.savefig('../Images/LR_SH_LatVWindSpeed.png')
# Out:
# The r value is: -0.14
# The linear equation is:y = -0.06x + 6.4
